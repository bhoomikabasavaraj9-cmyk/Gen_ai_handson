# %%
# %pip install langchain langchain-groq python-dotenv --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 6.8 MB/s eta 0:00:00

# %%
from dotenv import load_dotenv
load_dotenv()

import os, getpass
from langchain_groq import ChatGroq

if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API Key: ")

llm = ChatGroq(model="llama-3.1-8b-instant", temperature=0.0)
# Out:
# Enter your Groq API Key: ··········

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

chain = ChatPromptTemplate.from_template(
    "For the movie '{movie}', tell me its release year and calculate how many years ago it was from today."
) | llm | StrOutputParser()

print(chain.invoke({"movie": "Titanic"}))
# Out:
# The movie 'Titanic' was released in 1997.
#
# To calculate how many years ago it was released, I'll subtract the release year from the current year (2024).
#
# 2024 - 1997 = 27 years
#
# So, the movie 'Titanic' was released 27 years ago.
